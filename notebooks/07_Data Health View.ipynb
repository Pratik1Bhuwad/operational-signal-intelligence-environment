# %%
import pandas as pd

data_health = pd.DataFrame({
    "Metric": [
        "Missing Values",
        "Duplicate Records",
        "Demand Rows",
        "Generation Rows",
        "Forecast Rows"
    ],
    "Value": [
        0,
        0,
        17520,
        17520,
        17520
    ]
})



data_health
# Out:
#               Metric  Value
# 0     Missing Values      0
# 1  Duplicate Records      0
# 2        Demand Rows  17520
# 3    Generation Rows  17520
# 4      Forecast Rows  17520

# %%
data_health.to_csv(
    "D:/operational-signal-intelligence-environment/outputs/data_health_summary.csv",
    index=False
)
