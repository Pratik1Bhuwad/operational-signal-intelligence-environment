# %%
import pandas as pd

# %%
demand = pd.read_csv("D:/operational-signal-intelligence-environment/data/raw/national_demand.csv")

generation = pd.read_csv("D:/operational-signal-intelligence-environment/data/raw/generation_mix.csv")

forecast = pd.read_csv("D:/operational-signal-intelligence-environment/data/raw/forecast_performance.csv")

# %%
print("Demand:", demand.shape)
print("Generation:", generation.shape)
print("Forecast:", forecast.shape)
# Out:
# Demand: (17520, 22)
# Generation: (305579, 34)
# Forecast: (89086, 11)

# %%
demand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17520 entries, 0 to 17519
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SETTLEMENT_DATE            17520 non-null  object
#  1   SETTLEMENT_PERIOD          17520 non-null  int64
#  2   ND                         17520 non-null  int64
#  3   TSD                        17520 non-null  int64
#  4   ENGLAND_WALES_DEMAND       17520 non-null  int64
#  5   EMBEDDED_WIND_GENERATION   17520 non-null  int64
#  6   EMBEDDED_WIND_CAPACITY     17520 non-null  int64
#  7   EMBEDDED_SOLAR_GENERATION  17520 non-null  int64
#  8   EMBEDDED_SOLAR_CAPACITY    17520 non-null  int64
#  9   NON_BM_STOR                17520 non-null  int64
#  10  PUMP_STORAGE_PUMPING       17520 non-null  int64
#  11  SCOTTISH_TRANSFER          17520 non-null  int64
#  12  IFA_FLOW                   17520 non-null  int64
# ...

# %%
generation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305579 entries, 0 to 305578
# Data columns (total 34 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DATETIME          305579 non-null  object
#  1   GAS               305579 non-null  float64
#  2   COAL              305579 non-null  float64
#  3   NUCLEAR           305579 non-null  float64
#  4   WIND              305579 non-null  float64
#  5   WIND_EMB          305579 non-null  float64
#  6   HYDRO             305579 non-null  float64
#  7   IMPORTS           305579 non-null  float64
#  8   BIOMASS           305579 non-null  float64
#  9   OTHER             305579 non-null  float64
#  10  SOLAR             305579 non-null  float64
#  11  STORAGE           305579 non-null  float64
#  12  GENERATION        305579 non-null  float64
#  13  CARBON_INTENSITY  305579 non-null  float64
#  14  LOW_CARBON        305579 non-null  float64
# ...

# %%
forecast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89086 entries, 0 to 89085
# Data columns (total 11 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Month                                     89086 non-null  object
#  1   Date                                      89086 non-null  object
#  2   Datetime                                  89086 non-null  object
#  3   Settlement_Period                         89086 non-null  int64
#  4   Demand_Forecast                           89086 non-null  int64
#  5   Demand_Outturn                            89086 non-null  int64
#  6   TRIAD_Avoidance_Estimate                  89086 non-null  int64
#  7   TRIAD_Avoidance_Corrected_Demand_Outturn  89086 non-null  int64
#  8   APE                                       89086 non-null  float64
#  9   Absolute_Error                            89086 non-null  int64
# ...

# %%
demand.isnull().sum()
# Out:
# SETTLEMENT_DATE              0
# SETTLEMENT_PERIOD            0
# ND                           0
# TSD                          0
# ENGLAND_WALES_DEMAND         0
# EMBEDDED_WIND_GENERATION     0
# EMBEDDED_WIND_CAPACITY       0
# EMBEDDED_SOLAR_GENERATION    0
# EMBEDDED_SOLAR_CAPACITY      0
# NON_BM_STOR                  0
# PUMP_STORAGE_PUMPING         0
# SCOTTISH_TRANSFER            0
# IFA_FLOW                     0
# IFA2_FLOW                    0
# BRITNED_FLOW                 0
# MOYLE_FLOW                   0
# EAST_WEST_FLOW               0
# NEMO_FLOW                    0
# NSL_FLOW                     0
# ELECLINK_FLOW                0
# VIKING_FLOW                  0
# GREENLINK_FLOW               0
# dtype: int64

# %%
generation.isnull().sum()
# Out:
# DATETIME            0
# GAS                 0
# COAL                0
# NUCLEAR             0
# WIND                0
# WIND_EMB            0
# HYDRO               0
# IMPORTS             0
# BIOMASS             0
# OTHER               0
# SOLAR               0
# STORAGE             0
# GENERATION          0
# CARBON_INTENSITY    0
# LOW_CARBON          0
# ZERO_CARBON         0
# RENEWABLE           0
# FOSSIL              0
# GAS_perc            0
# COAL_perc           0
# NUCLEAR_perc        0
# WIND_perc           0
# WIND_EMB_perc       0
# HYDRO_perc          0
# IMPORTS_perc        0
# BIOMASS_perc        0
# OTHER_perc          0
# SOLAR_perc          0
# STORAGE_perc        0
# GENERATION_perc     0
# LOW_CARBON_perc     0
# ZERO_CARBON_perc    0
# RENEWABLE_perc      0
# FOSSIL_perc         0
# dtype: int64

# %%
forecast.isnull().sum()
# Out:
# Month                                       0
# Date                                        0
# Datetime                                    0
# Settlement_Period                           0
# Demand_Forecast                             0
# Demand_Outturn                              0
# TRIAD_Avoidance_Estimate                    0
# TRIAD_Avoidance_Corrected_Demand_Outturn    0
# APE                                         0
# Absolute_Error                              0
# Publish_Datetime                            0
# dtype: int64

# %%
print(demand.duplicated().sum())
print(generation.duplicated().sum())
print(forecast.duplicated().sum())
# Out:
# 0
# 0
# 0
