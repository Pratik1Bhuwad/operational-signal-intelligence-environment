# %%
import pandas as pd

signals = pd.read_csv(
    "D:/operational-signal-intelligence-environment/outputs/signal_intelligence_table.csv"
)

signals.head()
# Out:
#              timestamp   signal_name severity  \
# 0  2025-01-02 15:30:00  Demand Spike     High
# 1  2025-01-02 16:00:00  Demand Spike     High
# 2  2025-01-02 16:30:00  Demand Spike     High
# 3  2025-01-02 17:00:00  Demand Spike     High
# 4  2025-01-02 17:30:00  Demand Spike     High
#
#                             reason  supporting_metric confidence
# 0  Demand exceeded spike threshold            38264.0       High
# 1  Demand exceeded spike threshold            39309.0       High
# 2  Demand exceeded spike threshold            40412.0       High
# 3  Demand exceeded spike threshold            41103.0       High
# 4  Demand exceeded spike threshold            41589.0       High

# %%
signal_metadata = {

    "Demand Spike": {
        "impact_area": "Grid Demand",
        "owner": "Regional Controller",
        "resolution_target": "2 Hours",
        "operational_consequence":
        "Potential grid stress due to elevated demand"
    },

    "Forecast Failure": {
        "impact_area": "Forecasting",
        "owner": "Forecast Analyst",
        "resolution_target": "4 Hours",
        "operational_consequence":
        "Reduced forecasting reliability"
    },

    "Low Renewable Window": {
        "impact_area": "Sustainability",
        "owner": "Energy Operations Team",
        "resolution_target": "6 Hours",
        "operational_consequence":
        "Increased dependence on fossil generation"
    },

    "High Carbon Period": {
        "impact_area": "Carbon Management",
        "owner": "Sustainability Manager",
        "resolution_target": "4 Hours",
        "operational_consequence":
        "Elevated carbon emissions"
    },

    "Supply Stress": {
        "impact_area": "Grid Capacity",
        "owner": "Regional Controller",
        "resolution_target": "1 Hour",
        "operational_consequence":
        "Potential supply shortfall"
    },

    "Generation Surplus": {
        "impact_area": "Generation Management",
        "owner": "Operations Team",
        "resolution_target": "6 Hours",
        "operational_consequence":
        "Excess generation capacity available"
    },

    "Renewable Surge": {
        "impact_area": "Renewable Operations",
        "owner": "Renewable Operations Team",
        "resolution_target": "4 Hours",
        "operational_consequence":
        "Exceptional renewable contribution"
    },

    "Demand Drop": {
        "impact_area": "Demand Management",
        "owner": "Operations Team",
        "resolution_target": "4 Hours",
        "operational_consequence":
        "Demand significantly below expected levels"
    }

}

# %%
signals["impact_area"] = signals["signal_name"].apply(
    lambda x: signal_metadata[x]["impact_area"]
)

signals["owner"] = signals["signal_name"].apply(
    lambda x: signal_metadata[x]["owner"]
)

signals["resolution_target"] = signals["signal_name"].apply(
    lambda x: signal_metadata[x]["resolution_target"]
)

signals["operational_consequence"] = signals["signal_name"].apply(
    lambda x: signal_metadata[x]["operational_consequence"]
)

# %%
signals.shape
# Out:
# (20909, 10)

# %%
signals.head()
# Out:
#              timestamp   signal_name severity  \
# 0  2025-01-02 15:30:00  Demand Spike     High
# 1  2025-01-02 16:00:00  Demand Spike     High
# 2  2025-01-02 16:30:00  Demand Spike     High
# 3  2025-01-02 17:00:00  Demand Spike     High
# 4  2025-01-02 17:30:00  Demand Spike     High
#
#                             reason  supporting_metric confidence  impact_area  \
# 0  Demand exceeded spike threshold            38264.0       High  Grid Demand
# 1  Demand exceeded spike threshold            39309.0       High  Grid Demand
# 2  Demand exceeded spike threshold            40412.0       High  Grid Demand
# 3  Demand exceeded spike threshold            41103.0       High  Grid Demand
# 4  Demand exceeded spike threshold            41589.0       High  Grid Demand
#
#                  owner resolution_target  \
# 0  Regional Controller           2 Hours
# 1  Regional Controller           2 Hours
# 2  Regional Controller           2 Hours
# 3  Regional Controller           2 Hours
# 4  Regional Controller           2 Hours
#
#                         operational_consequence
# 0  Potential grid stress due to elevated demand
# 1  Potential grid stress due to elevated demand
# 2  Potential grid stress due to elevated demand
# 3  Potential grid stress due to elevated demand
# 4  Potential grid stress due to elevated demand

# %%
signals.to_csv(
    "D:/operational-signal-intelligence-environment/outputs/signal_priority_table.csv",
    index=False
)

print("Signal priority table generated successfully")
# Out:
# Signal priority table generated successfully
