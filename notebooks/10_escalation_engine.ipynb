# %%
import pandas as pd

incident_df = pd.read_csv(
    "D:/operational-signal-intelligence-environment/outputs/incident_table.csv"
)

incident_df.head()
# Out:
#   incident_id            timestamp              incident_type  \
# 0   INC-00001  2025-01-01 00:00:00  CURTAILMENT_RISK_INCIDENT
# 1   INC-00002  2025-01-01 00:30:00  CURTAILMENT_RISK_INCIDENT
# 2   INC-00003  2025-01-01 01:00:00  CURTAILMENT_RISK_INCIDENT
# 3   INC-00004  2025-01-01 01:30:00  CURTAILMENT_RISK_INCIDENT
# 4   INC-00005  2025-01-01 02:00:00  CURTAILMENT_RISK_INCIDENT
#
#                   contributing_signals severity  \
# 0  Renewable Surge, Generation Surplus   Medium
# 1  Renewable Surge, Generation Surplus   Medium
# 2  Renewable Surge, Generation Surplus   Medium
# 3  Renewable Surge, Generation Surplus   Medium
# 4  Renewable Surge, Generation Surplus   Medium
#
#                    business_impact                    recommended_response  \
# 0  Potential renewable curtailment  Evaluate renewable curtailment actions
# 1  Potential renewable curtailment  Evaluate renewable curtailment actions
# 2  Potential renewable curtailment  Evaluate renewable curtailment actions
# 3  Potential renewable curtailment  Evaluate renewable curtailment actions
# 4  Potential renewable curtailment  Evaluate renewable curtailment actions
#
#          escalation_path
# 0  Operator → Supervisor
# 1  Operator → Supervisor
# 2  Operator → Supervisor
# 3  Operator → Supervisor
# 4  Operator → Supervisor

# %%
def assign_escalation(severity):

    if severity == "Critical":
        return "Executive"

    elif severity == "High":
        return "Regional Controller"

    elif severity == "Medium":
        return "Supervisor"

    else:
        return "Operator"

# %%
incident_df["owner"] = (
    incident_df["severity"]
    .apply(assign_escalation)
)

# %%
def notification_group(owner):

    mapping = {

        "Operator":
            "Operations Team",

        "Supervisor":
            "Operations Supervisor",

        "Regional Controller":
            "Regional Leadership",

        "Executive":
            "Executive Leadership"

    }

    return mapping[owner]

# %%
incident_df["notification_group"] = (
    incident_df["owner"]
    .apply(notification_group)
)

# %%
def escalation_path(owner):

    paths = {

        "Operator":
            "Operator",

        "Supervisor":
            "Operator → Supervisor",

        "Regional Controller":
            "Operator → Supervisor → Regional Controller",

        "Executive":
            "Operator → Supervisor → Regional Controller → Executive"

    }

    return paths[owner]

# %%
incident_df["escalation_path"] = (
    incident_df["owner"]
    .apply(escalation_path)
)

# %%
escalation_queue = incident_df[
    [
        "incident_id",
        "timestamp",
        "incident_type",
        "severity",
        "owner",
        "notification_group",
        "escalation_path"
    ]
]

# %%
escalation_queue.head()
# Out:
#   incident_id            timestamp              incident_type severity  \
# 0   INC-00001  2025-01-01 00:00:00  CURTAILMENT_RISK_INCIDENT   Medium
# 1   INC-00002  2025-01-01 00:30:00  CURTAILMENT_RISK_INCIDENT   Medium
# 2   INC-00003  2025-01-01 01:00:00  CURTAILMENT_RISK_INCIDENT   Medium
# 3   INC-00004  2025-01-01 01:30:00  CURTAILMENT_RISK_INCIDENT   Medium
# 4   INC-00005  2025-01-01 02:00:00  CURTAILMENT_RISK_INCIDENT   Medium
#
#         owner     notification_group        escalation_path
# 0  Supervisor  Operations Supervisor  Operator → Supervisor
# 1  Supervisor  Operations Supervisor  Operator → Supervisor
# 2  Supervisor  Operations Supervisor  Operator → Supervisor
# 3  Supervisor  Operations Supervisor  Operator → Supervisor
# 4  Supervisor  Operations Supervisor  Operator → Supervisor

# %%
escalation_queue.to_csv(
    "D:/operational-signal-intelligence-environment/outputs/escalation_queue.csv",
    index=False
)

print("Escalation queue generated successfully")
# Out:
# Escalation queue generated successfully

# %%
escalation_queue.shape
# Out:
# (5526, 7)

# %%
escalation_queue["owner"].value_counts()
# Out:
# owner
# Supervisor             3261
# Operator               1610
# Regional Controller     578
# Executive                77
# Name: count, dtype: int64

# %%
escalation_queue.head()
# Out:
#   incident_id            timestamp              incident_type severity  \
# 0   INC-00001  2025-01-01 00:00:00  CURTAILMENT_RISK_INCIDENT   Medium
# 1   INC-00002  2025-01-01 00:30:00  CURTAILMENT_RISK_INCIDENT   Medium
# 2   INC-00003  2025-01-01 01:00:00  CURTAILMENT_RISK_INCIDENT   Medium
# 3   INC-00004  2025-01-01 01:30:00  CURTAILMENT_RISK_INCIDENT   Medium
# 4   INC-00005  2025-01-01 02:00:00  CURTAILMENT_RISK_INCIDENT   Medium
#
#         owner     notification_group        escalation_path
# 0  Supervisor  Operations Supervisor  Operator → Supervisor
# 1  Supervisor  Operations Supervisor  Operator → Supervisor
# 2  Supervisor  Operations Supervisor  Operator → Supervisor
# 3  Supervisor  Operations Supervisor  Operator → Supervisor
# 4  Supervisor  Operations Supervisor  Operator → Supervisor
