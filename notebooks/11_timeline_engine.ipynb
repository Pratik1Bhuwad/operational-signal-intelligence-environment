# %%
import pandas as pd

incident_df = pd.read_csv(
    "D:/operational-signal-intelligence-environment/outputs/incident_table.csv"
)

escalation_df = pd.read_csv(
    "D:/operational-signal-intelligence-environment/outputs/escalation_queue.csv"
)

# %%
timeline_records = []

# %%
for _, row in incident_df.iterrows():

    timeline_records.append({

        "timestamp": row["timestamp"],

        "event_type":
            "Incident Created",

        "incident_id":
            row["incident_id"],

        "details":
            row["incident_type"]

    })

# %%
for _, row in escalation_df.iterrows():

    timeline_records.append({

        "timestamp": row["timestamp"],

        "event_type":
            "Escalated",

        "incident_id":
            row["incident_id"],

        "details":
            row["owner"]

    })

# %%
from datetime import timedelta

# %%
for _, row in escalation_df.iterrows():

    resolution_time = (
        pd.to_datetime(row["timestamp"])
        + timedelta(hours=2)
    )

    timeline_records.append({

        "timestamp":
            resolution_time,

        "event_type":
            "Resolved",

        "incident_id":
            row["incident_id"],

        "details":
            "Incident Closed"

    })

# %%
timeline_df = pd.DataFrame(
    timeline_records
)

# %%
timeline_df["timestamp"] = pd.to_datetime(
    timeline_df["timestamp"]
)

timeline_df = timeline_df.sort_values(
    by="timestamp"
)

# %%
timeline_df.shape
# Out:
# (16578, 4)

# %%
timeline_df.head(20)
# Out:
#                 timestamp        event_type incident_id  \
# 0     2025-01-01 00:00:00  Incident Created   INC-00001
# 5526  2025-01-01 00:00:00         Escalated   INC-00001
# 1     2025-01-01 00:30:00  Incident Created   INC-00002
# 5527  2025-01-01 00:30:00         Escalated   INC-00002
# 2     2025-01-01 01:00:00  Incident Created   INC-00003
# 5528  2025-01-01 01:00:00         Escalated   INC-00003
# 5529  2025-01-01 01:30:00         Escalated   INC-00004
# 3     2025-01-01 01:30:00  Incident Created   INC-00004
# 4     2025-01-01 02:00:00  Incident Created   INC-00005
# 11052 2025-01-01 02:00:00          Resolved   INC-00001
# 5530  2025-01-01 02:00:00         Escalated   INC-00005
# 5531  2025-01-01 02:30:00         Escalated   INC-00006
# 11053 2025-01-01 02:30:00          Resolved   INC-00002
# 5     2025-01-01 02:30:00  Incident Created   INC-00006
# 11054 2025-01-01 03:00:00          Resolved   INC-00003
# 7     2025-01-01 03:00:00  Incident Created   INC-00008
# 5532  2025-01-01 03:00:00         Escalated   INC-00007
# 5533  2025-01-01 03:00:00         Escalated   INC-00008
# 6     2025-01-01 03:00:00  Incident Created   INC-00007
# 11055 2025-01-01 03:30:00          Resolved   INC-00004
#
#                          details
# 0      CURTAILMENT_RISK_INCIDENT
# 5526                  Supervisor
# 1      CURTAILMENT_RISK_INCIDENT
# 5527                  Supervisor
# 2      CURTAILMENT_RISK_INCIDENT
# 5528                  Supervisor
# 5529                  Supervisor
# 3      CURTAILMENT_RISK_INCIDENT
# 4      CURTAILMENT_RISK_INCIDENT
# 11052            Incident Closed
# 5530                  Supervisor
# 5531                  Supervisor
# 11053            Incident Closed
# 5      CURTAILMENT_RISK_INCIDENT
# 11054            Incident Closed
# 7      CURTAILMENT_RISK_INCIDENT
# 5532                    Operator
# 5533                  Supervisor
# 6       OVER_GENERATION_INCIDENT
# 11055            Incident Closed

# %%
timeline_df["event_type"].value_counts()
# Out:
# event_type
# Incident Created    5526
# Escalated           5526
# Resolved            5526
# Name: count, dtype: int64

# %%
timeline_df = timeline_df.sort_values(
    by=["timestamp", "incident_id"]
).reset_index(drop=True)

# %%
timeline_df.head()
# Out:
#             timestamp        event_type incident_id                    details
# 0 2025-01-01 00:00:00  Incident Created   INC-00001  CURTAILMENT_RISK_INCIDENT
# 1 2025-01-01 00:00:00         Escalated   INC-00001                 Supervisor
# 2 2025-01-01 00:30:00  Incident Created   INC-00002  CURTAILMENT_RISK_INCIDENT
# 3 2025-01-01 00:30:00         Escalated   INC-00002                 Supervisor
# 4 2025-01-01 01:00:00  Incident Created   INC-00003  CURTAILMENT_RISK_INCIDENT

# %%
timeline_df.to_csv(
    "D:/operational-signal-intelligence-environment/outputs/incident_timeline.csv",
    index=False
)

print(
    "Timeline generated successfully"
)
# Out:
# Timeline generated successfully
